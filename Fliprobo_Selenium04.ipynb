# %%
# importing all the requaired libraries.
import selenium
import pandas as pd
import time
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date E) Views

# %%
# opening webdriver
driver=webdriver.Chrome(r"//Users/prajwalkunder/Downloads/chromedriver")

# %%
# opening wikipedia
driver.get(' https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/')

# %%
#clicking element.
driver.find_element_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table/tbody/tr/td/span/a/i').click()

# %%
# clicking elements
driver.find_element_by_xpath('/html/body/div[3]/div[3]/div[4]/div[3]/ul/li[1]/div[1]').click()

# %%
# Creating empty list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#writing for loop for Rank.
dt=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for d in dt:
    if d.text is None :
        Rank.append('-')
    else:
        Rank.append(d.text)

# %%
#checking length
print(len(Rank))
# Out:
# 49

# %%
#writing for loop for Name.
dt=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Name.append('-')
    else:
        Name.append(d.text)

# %%
#checking length
print(len(Name))
# Out:
# 49

# %%
#writnig for loop for Artist.
dt=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Artist.append('-')
    else:
        Artist.append(d.text)

# %%
#cheking length
print(len(Artist))
# Out:
# 196

# %%
#writnig for loop for Upload date.
dt=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        Upload_date.append('-')
    else:
        Upload_date.append(d.text)

# %%
#checking length
print(len(Upload_date))
# Out:
# 49

# %%
#writing for loop for  Views.
dt=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Views.append('-')
    else:
        Views.append(d.text)

# %%
#checking length
print(len(Views))
# Out:
# 49

# %%
table=pd.DataFrame({})

table['Rank']=Rank[:30]
table['Name']=Name[:30]
table['Artist']=Artist[:30]
table['Upload Date']=Upload_date[:30]
table['Views']=Views[:30]

# %%
table
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                       "Johny Johny Yes Papa"[25]
# 3    4.                               "Shape of You"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                  "Bath Song"[31]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 8    9.                                "Uptown Funk"[33]
# 9   10.                              "Gangnam Style"[34]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                             "Dame Tu Cosita"[38]
# 13  14.                                      "Sorry"[39]
# 14  15.                                       "Roar"[40]
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# opening webdriver
driver=webdriver.Chrome(r"//Users/prajwalkunder/Downloads/chromedriver")

# %%
# opening website www.bcci.tv
driver.get('https://www.bcci.tv/')

# %%
#getting international fixture
driver.find_element_by_xpath('//div[@class="navigation__drop-down drop-down drop-down--reveal-on-hover"]').click()

# %%
#getting fixtures
driver.find_element_by_xpath('/html/body/footer/div/nav/ul/li[2]/ul/li[1]').click()

# %%
#extracting month data
month=[]
try:
    Month=driver.find_elements_by_xpath('//h3[@class="event-list__date js-date"]')
    for i in Month:
        month.append(i.text)
except NoSuchElementException:
    month.append('-')

# %%
# extracting match title data
macth_title=[]
try:
    title=driver.find_elements_by_xpath('//span[@class="u-unskewed-text fixture__tournament-label u-truncated"]')
    for i in title:
        match_title.append(i.text)
except NoSuchElementException:
    match_title.append('-')

# %%
#extracting series data
Series=[]
try:
    series=driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]')
    for i in series:
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')

# %%
#extracting place data
Place=[]
try:
    place=driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/span')
    for i in place:
        Place.append(i.text)
except NoSuchElementException:
    Place.append('-')

# %%
#extracting date data
Date=[]
try:
    date=driver.find_elements_by_xpath('//span[@class="fixture__date"]')
    for i in date:
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')

# %%
#extracting time data
Time=[]
try:
    time=driver.find_elements_by_xpath('//span[@class="fixture__time"]')
    for i in time:
        Time.append(i.text)
except NoSuchElementException:
    Time.append('-')

# %%
#creating dataframe
df=pd.DataFrame({})

df['Match Title']=match_title
df['Series']=Series
df['Place']=Place
df['Date']=Date
df['Time']=Time

# %%
df
# Out:
#             Match Title    Series                     Place Date       Time
# 0  ENGLAND V INDIA 2021  1st Test  Trent Bridge, Nottingham   04  15:30 IST
# 1  ENGLAND V INDIA 2021  2nd Test            Lord's, London   12  15:30 IST
# 2  ENGLAND V INDIA 2021  3rd Test         Headingley, Leeds   25  15:30 IST
# 3  ENGLAND V INDIA 2021  4th Test          The Oval, London   02  15:30 IST
# 4  ENGLAND V INDIA 2021  5th Test  Old Trafford, Manchester   10  15:30 IST

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
#    You need to find following details:
#    A) Name
#    B) Description
#    Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#getting web https://www.guru99.com/.
driver.get('https://www.guru99.com/')

# %%
#getting web element and clicking.
driver.find_element_by_xpath('//a[@title="Selenium"]').click()

# %%
#getting web element and clicking.
driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()

# %%
#Creating empty list.
Name=[]
Description=[]

# %%
#Creating for loop for Name to scrape data.
dt=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for d in dt:
    Name.append(d.text)

# %%
#Creating for loop for Description to scrape data.
dt=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for d in dt:
    Description.append(d.text)

# %%
#Creating dataframe
df=pd.DataFrame({})

df['Name']=Name[:41]
df['Description']=Description[:41]

# %%
df
# Out:
#                                    Name  \
# 0                        Exception name
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# ...

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com. Url =              http://statisticstimes.com/
#    You have to find following details:
#    A) Rank
#    B) State
#    C) GSDP at current price (19-20)
#    D) GSDP at current price (18-19)
#    E) Share(18-19)
#    F) GDP($ billion)
#    Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#opening website
driver.get('http://statisticstimes.com/')

# %%
# selecting heading of econamy
economy=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/button')
economy.click()

# %%
#Getting subtitle india
india=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')
url=india.get_attribute('href')
url
# Out:
# 'http://statisticstimes.com/economy/india-statistics.php'

# %%
#getting url for India
driver.get(url)

# %%
#getting India state GDP url
GDP=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
India_GDP=GDP.get_attribute('href')
India_GDP
# Out:
# 'http://statisticstimes.com/economy/india/indian-states-gdp.php'

# %%
# getting url of India_GDP url
driver.get(India_GDP)

# %%
#extracting rank data
Rank=[]
try:
    rank=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#extracting state data
State=[]
try:
    state=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

# %%
#extracting GDP (19-20) current price data
GSDP_price=[]
try:
    gsdp=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in gsdp:
        GSDP_price.append(i.text)
except NoSuchElementException:
    GSDP_price.append('-')

# %%
#extracting GDP current price(18-19) data
GSDP_price18=[]
try:
    gsdp=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in gsdp:
        GSDP_price18.append(i.text)
except NoSuchElementException:
    GSDP_price18.append('-')

# %%
#extracting share price(18-19) data
Share=[]
try:
    share=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')

# %%
#extracting GDP billion data
GDP_billion=[]
try:
    billion=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in billion:
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append('-')

# %%
# creating data frame
df=pd.DataFrame({})

df['Rank']=Rank
df['State']=State
df['GSDP Current Price(19-20)']=GSDP_price
df['GSDP Current Price(18-19)']=GSDP_price18
df['Share(18-19)']=Share
df['GDP($ Billion)']=GDP_billion

# %%
df
# Out:
#    Rank                      State GSDP Current Price(19-20)  \
# 0     1                Maharashtra                         -
# 1     2                 Tamil Nadu                 1,845,853
# 2     3              Uttar Pradesh                 1,687,818
# 3     4                    Gujarat                         -
# 4     5                  Karnataka                 1,631,977
# 5     6                West Bengal                 1,253,832
# 6     7                  Rajasthan                 1,020,989
# 7     8             Andhra Pradesh                   972,782
# 8     9                  Telangana                   969,604
# 9    10             Madhya Pradesh                   906,672
# 10   11                     Kerala                         -
# 11   12                      Delhi                   856,112
# 12   13                    Haryana                   831,610
# 13   14                      Bihar                   611,804
# ...

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#getting url
driver.get('https://github.com/')

# %%
#selecting explore button
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details').click()

# %%
# selecting trend button
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]').click()

# %%
#extacting title data
title=[]
try:
    repositories=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]/a')
    for i in repositories:
        title.append(i.text)
except NoSuchElementException:
    title.append('-')

# %%
title
# Out:
# ['commaai / openpilot',
#  'Azure / azure-sdk-for-net',
#  'bytedance / Fastbot_iOS',
#  'clouDr-f2e / rubick',
#  'MoienTajik / AspNetCore-Developer-Roadmap',
#  'microsoft / ML-For-Beginners',
#  'apache / pinot',
#  'SigmaHQ / sigma',
#  'ibraheemdev / modern-unix',
#  'klezVirus / inceptor',
#  '0x727 / SqlKnife_0x727',
#  'mytechnotalent / Reverse-Engineering',
#  'sysprog21 / lkmpg',
#  'microsoft / PowerToys',
#  'RasaHQ / rasa',
#  'geekxh / hello-algorithm',
#  'terraform-aws-modules / terraform-aws-eks',
#  'riscv2os / riscv2os',
#  '0x727 / ShuiZe_0x727',
#  'ryanmcdermott / clean-code-javascript',
#  'vlang / v',
#  'MunGell / awesome-for-beginners',
#  'doocs / jvm',
#  'JetBrains / compose-jb',
#  'eugenp / tutorials']

# %%
#extacting description data
description=[]
try:
    repositories=driver.find_elements_by_xpath('//p[@class="col-9 color-text-secondary my-1 pr-4"]')
    for i in repositories:
        description.append(i.text)
except NoSuchElementException:
    description.append('-')

# %%
description
# Out:
# ['openpilot is an open source driver assistance system. openpilot performs the functions of Automated Lane Centering and Adaptive Cruise Control for over 100 supported car makes and models.',
#  'This repository is for active development of the Azure SDK for .NET. For consumers of the SDK we recommend visiting our public developer docs at https://docs.microsoft.com/en-us/dotnet/azure/ or our versioned developer docs at https://azure.github.io/azure-sdk-for-net.',
#  'About Fastbot(2.0) is a model-based testing tool for modeling GUI transitions to discover app stability problems',
#  '🔧 基于 electron 的开源工具箱，自由集成丰富插件。',
#  'Roadmap to becoming an ASP.NET Core developer in 2021',
#  '12 weeks, 25 lessons, 50 quizzes, classic Machine Learning for all',
#  'Apache Pinot (Incubating) - A realtime distributed OLAP datastore',
#  'Generic Signature Format for SIEM Systems',
#  'A collection of modern/faster/saner alternatives to common unix commands.',
# ...

# %%
#extacting url data
url=[]
try:
    contributors=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]/a')
    for i in contributors:
        url.append(i.get_attribute('href'))
except NoSuchElementException:
    url.append('-')

# %%
url
# Out:
# ['https://github.com/commaai/openpilot',
#  'https://github.com/Azure/azure-sdk-for-net',
#  'https://github.com/bytedance/Fastbot_iOS',
#  'https://github.com/clouDr-f2e/rubick',
#  'https://github.com/MoienTajik/AspNetCore-Developer-Roadmap',
#  'https://github.com/microsoft/ML-For-Beginners',
#  'https://github.com/apache/pinot',
#  'https://github.com/SigmaHQ/sigma',
#  'https://github.com/ibraheemdev/modern-unix',
#  'https://github.com/klezVirus/inceptor',
#  'https://github.com/0x727/SqlKnife_0x727',
#  'https://github.com/mytechnotalent/Reverse-Engineering',
#  'https://github.com/sysprog21/lkmpg',
#  'https://github.com/microsoft/PowerToys',
#  'https://github.com/RasaHQ/rasa',
#  'https://github.com/geekxh/hello-algorithm',
#  'https://github.com/terraform-aws-modules/terraform-aws-eks',
#  'https://github.com/riscv2os/riscv2os',
#  'https://github.com/0x727/ShuiZe_0x727',
#  'https://github.com/ryanmcdermott/clean-code-javascript',
#  'https://github.com/vlang/v',
# ...

# %%
#extacting count data
count=[]
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        contributors=driver.find_elements_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[4]/div/h2/a/span')
        for i in contributors:
            count.append(i.text)
    except NoSuchElementException:
        count.append('-')
count
# Out:
# ['210', '4.2k', '19', '9', '14', '197', '6', '', '', '', '', '51']

# %%
#extacting language data
language=[]
try:
    used=driver.find_elements_by_xpath('//span[@class="d-inline-block ml-0 mr-3"]')
    for i in used:
        language.append(i.text)
except NoSuchElementException:
    language.append('-')
language
# Out:
# ['C++',
#  'C#',
#  'Objective-C',
#  'JavaScript',
#  'Jupyter Notebook',
#  'Java',
#  'Python',
#  'Assembly',
#  'C++',
#  'C',
#  'TeX',
#  'C#',
#  'Python',
#  'Java',
#  'HCL',
#  'Python',
#  'JavaScript',
#  'V',
#  'Java',
#  'Kotlin',
#  'Java']

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
#Getting web element https://www.billboard.com/.
driver.get('https://www.billboard.com/')

# %%
#clicking button
button=driver.find_elements_by_xpath('//nav[@class="header__subnav bg--light"]/ul/li[3]/a')
button[0].click()

# %%
#Creating empty list.
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
#creating for loop for song name to extract data.
dt=driver.find_elements_by_xpath('//span[@class="chart-element__information__song text--truncate color--primary"]')
for i in dt:
    if i.text is None:
        Song_name.append('-')
    else:
        Song_name.append(i.text)

# %%
#creating for loop for Artist name to extract data
dt=driver.find_elements_by_xpath('//span[@class="chart-element__information__artist text--truncate color--secondary"]')
for i in dt:
    if i.text is None:
        Artist_name.append('-')
    else:
        Artist_name.append(i.text)

# %%
#creating for loop for last_week_rank to extract data.
dt=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
for i in dt:
    if i.text is None:
        Last_week_rank.append('-')
    else:
        Last_week_rank.append(i.text)

# %%
#creating for loop for Peak rank to extract data
dt=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')
for i in dt:
    if i.text is None:
        Peak_rank.append('-')
    else:
        Peak_rank.append(i.text)

# %%
#creating for loop for week on board to extract data.
dt=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')
for i in dt:
    if i.text is None:
        Weeks_on_board.append('-')
    else:
        Weeks_on_board.append(i.text)

# %%
#creating data frame 
df=pd.DataFrame({})

df['Song Name']=Song_name
df['Artist Name']=Artist_name
df['Last Week Rank']=Last_week_rank
df['Peak Rank']=Peak_rank
df['Weeks On Board']=Weeks_on_board

# %%
df
# Out:
#           Song Name                                        Artist Name  \
# 0            Butter                                                BTS
# 1     Industry Baby                            Lil Nas X & Jack Harlow
# 2          Good 4 U                                     Olivia Rodrigo
# 3              Stay                      The Kid LAROI & Justin Bieber
# 4        Levitating                          Dua Lipa Featuring DaBaby
# ..              ...                                                ...
# 95     Minimum Wage                                      Blake Shelton
# 96          Working                                Tate McRae X Khalid
# 97      Holy Smokes                Trippie Redd Featuring Lil Uzi Vert
# 98        WUSYANAME  Tyler, The Creator Featuring YoungBoy Never Br...
# 99  Still Chose You                    The Kid LAROI Featuring Mustard
#
#    Last Week Rank Peak Rank Weeks On Board
# 0               1         1             10
# ...

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
#getting website url https://www.naukri.com/
driver.get('https://www.naukri.com/')

# %%
#clicking button
button=driver.find_elements_by_xpath('//ul[@class="midSec menu"]/li[2]')
button[0].click()

# %%
# switching tab in web driver
driver.switch_to.window(driver.window_handles[1])

# %%
# sending Data science in search bar
search_job=driver.find_element_by_xpath("//input[@class='sugInp']")
search_job.send_keys('Data Science')

# %%
# clicking search button
search_btn=driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search_btn.click()

# %%
#creating empty list
name=[]
designation=[]
company=[]
skills_required=[]
location=[]

# %%
#writing for loop to 120 page
for page in range(0,120):

#writing for loop for name data
    dt=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
    for i in dt:
        if i.text is None:
            name.append('-')
        else:
            name.append(i.text)
        
#writing for loop for designation data
    dt=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
    for i in dt:
        if i.text is None:
            designation.append('-')
        else:
            designation.append(i.text)

#writing for loop for company data       
    dt=driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
    for i in dt:
        if i.text is None:
            company.append('-')
        else:
            company.append(i.text)
            
#writing for loop for skill data
    dt=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
    for i in dt:
        if i.text is None:
            skills_required.append('-')
        else:
            skills_required.append(i.text)
            
#writing for loop for location data            
    dt=driver.find_elements_by_xpath('//small[@class="ellipsis"]')
    for i in dt:
        if i.text is None:
            location.append('-')
        else:
            location.append(i.text)

# %%
#checking length
print(len(name),len(designation),len(company),len(skills_required),len(location))
# Out:
# 9400 9400 9400 9400 9004

# %%
#creating data frame
df=pd.DataFrame({})

df['Name']=name[:9000]
df['Designation']=designation[:9000]
df['Company']=company[:9000]
df['Location']=location[:9000]
df['Skills they hire for']=skills_required[:9000]

# %%
df
# Out:
#                           Name               Designation  \
# 0                 Aakash Harit                HR Manager
# 1         shravan Kumar Gaddam         Company Recruiter
# 2     MARSIAN Technologies LLP                Company HR
# 3                 Anik Agrawal         Company Recruiter
# 4                 subhas patel               Founder CEO
# ...                        ...                       ...
# 8995                   Ashwini  Director Global Delivery
# 8996              Balaji Kolli                Co Founder
# 8997            Rajani Nagaraj                HR Manager
# 8998               ROHIT Kumar                 Architect
# 8999            Amir Chowdhury          Managing Partner
#
#                                     Company                  Location  \
# 0                      Data Science Network                     Delhi
# 1             Shore Infotech India Pvt. Ltd  Hyderabad / Secunderabad
# ...

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#getting url
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
#creating empty list
book_name=[]
author_name=[]
volumes_sold=[]
publisher=[]
genre=[]

# %%
#creating for loop to extract book name data
dt=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in dt:
    if i.text is None:
        book_name.append('-')
    else:
        book_name.append(i.text)

# %%
#creating for loop to extract author name data
dt=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in dt:
    if i.text is None:
        author_name.append('-')
    else:
        author_name.append(i.text)

# %%
#creating for loop to extract volums sold data.
dt=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in dt:
    if i.text is None:
        volumes_sold.append('-')
    else:
        volumes_sold.append(i.text)

# %%
#creating for loop to extract publisher data
dt=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in dt:
    if i.text is None:
        publisher.append('-')
    else:
        publisher.append(i.text)

# %%
#creating for loop to extract genre
dt=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in dt:
    if i.text is None:
        genre.append('-')
    else:
        genre.append(i.text)

# %%
#checking lenght of data 
print(len(book_name),len(author_name),len(volumes_sold),len(publisher),len(genre))
# Out:
# 100 100 100 100 100

# %%
#creating dataframe
df=pd.DataFrame({})

df['Book Name']=book_name
df['Author Nmae']=author_name
df['Volumes Sold']=volumes_sold
df['Publisher']=publisher
df['Genre']=genre

# %%
df
# Out:
#                                             Book Name       Author Nmae  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details: A) Name
# B) Year span
# C) Genre
# D) Run time E) Ratings F) Votes

# %%
#Getting website https://www.imdb.com/list/ls095964455/.
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
#creating empty list
name=[]
year_span=[]
genre=[]
run_time=[]
ratings=[]
votes=[]

# %%
#creating for loop to extract name data.
dt=driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for i in dt:
    if i.text is None:
        name.append('-')
    else:
        name.append(i.text)

# %%
#creating for loop to extract year name data.
dt=driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for i in dt:
    if i.text is None:
        year_span.append('-')
    else:
        year_span.append(i.text)

# %%
#creating for loop to extract gener data.
dt=driver.find_elements_by_xpath('//span[@class="genre"]')
for i in dt:
    if i.text is None:
        genre.append('-')
    else:
        genre.append(i.text)

# %%
#creating for loop to extract run time data.
dt=driver.find_elements_by_xpath('//span[@class="runtime"]')
for i in dt:
    if i.text is None:
        run_time.append('-')
    else:
        run_time.append(i.text)

# %%
#creating for loop to extract rating data
dt=driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for i in dt:
    if i.text is None:
        ratings.append('-')
    else:
        ratings.append(i.text)

# %%
#creating for loop to extract votes data
dt=driver.find_elements_by_xpath('//span[@name="nv"]')
for i in dt:
    if i.text is None:
        votes.append('-')
    else:
        votes.append(i.text)

# %%
#checking length.
print(len(name),len(year_span),len(genre),len(run_time),len(votes),len(ratings))
# Out:
# 100 100 200 100 100 100

# %%
#creating data frame 
df=pd.DataFrame({})

df['Name']=name[:100]
df['Year Span']=year_span[:100]
df['Genre']=genre[:100]
df['Run Time']=run_time[:100]
df['Votes']=votes[:100]
df['Rating']=ratings[:100]

# %%
df
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time      Votes Rating
# 0    57 min  1,848,399    9.2
# ...

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name B) Data type
# C) Task
# D) Attribute type E) No of instances F) No of attribute G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
#getting url 
driver.get('https://archive.ics.uci.edu/')

# %%
#clicking button
dt=driver.find_element_by_xpath('//span[@class="normal"]/b')
dt.click()

# %%
#creating empty list
dataset_name=[]
data_type=[]
task=[]
attribute_type=[]
instances=[]
attribute=[]
year=[]

# %%
#creating for loop to extract dataset name
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b')
for i in dt:
    if i.text is None:
        dataset_name.append('-')
    else:
        dataset_name.append(i.text)

# %%
#creating for loop to extrct data type 
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[2]')
for i in dt:
    if i.text is None:
        data_type.append
    else:
        data_type.append(i.text)

# %%
#creating for loop to extract task data.
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[4]')
for i in dt:
    if i.text is None:
        task.append('-')
    else:
        task.append(i.text)

# %%
#creating for loop to extract attribute type data
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[4]')
for i in dt:
    if i.text is None:
        attribute_type.append('-')
    else:
        attribute_type.append(i.text)

# %%
#creating for loop to extract instances data
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[5]')
for i in dt:
    if i.text is None:
        instances.append('-')
    else:
        instances.append(i.text)

# %%
#creating for loop to extract attribute data
df=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[6]')
for i in dt:
    if i.text is None:
        attribute.append('-')
    else:
        attribute.append(i.text)

# %%
#creating for loop to extract year data
dt=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[7]')
for i in dt:
    if i.text is None:
        year.append('-')
    else:
        year.append(i.text)

# %%
#checking length.
print(len(dataset_name),len(data_type),len(task),len(attribute),len(instances),len(attribute),len(year))
# Out:
# 588 589 589 589 589 589 589

# %%
#creating dataset
df=pd.DataFrame({})

df['Dataset Name']=dataset_name[:588]
df['Data Type']=data_type[:588]
df['Task']=task[:588]
df['Attribute Type']=attribute_type[:588]
df['Instances']=instances[:588]
df['Attribute']=attribute[:588]
df['Year']=year[:588]

# %%
df
# Out:
#                          Dataset Name      Data Type  \
# 0                             Abalone     Data Types
# 1                               Adult  Multivariate
# 2                           Annealing  Multivariate
# 3        Anonymous Microsoft Web Data  Multivariate
# 4                          Arrhythmia
# ..                                ...            ...
# 583  in-vehicle coupon recommendation  Multivariate
# 584               Gait Classification  Multivariate
# 585         Wikipedia Math Essentials  Multivariate
# 586         Wikipedia Math Essentials   Time-Series
# 587      Synchronous Machine Data Set   Time-Series
#
#                             Task               Attribute Type    Instances  \
# 0                Attribute Types              Attribute Types  # Instances
# 1    Categorical, Integer, Real   Categorical, Integer, Real         4177
# 2          Categorical, Integer         Categorical, Integer        48842
# ...
